# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #### Vanesa
# #### Researcher

# %% [markdown]
# ##### I am interested in data science because I want to change my job and advance professionally

# %% [markdown]
# ### Assign a number to a letter and then do the addition.

# %%
a=1
b=2
print (a+b)
# Out:
# 3

# %% [markdown]
# 1 | 2 | 3
# --- | --- | ---
# *I* | `B` | **M**
